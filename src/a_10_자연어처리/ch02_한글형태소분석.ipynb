# %% [markdown]
# # 1. 자연어 처리
# - 자연어(사람들이 일상적으로 사용하는 언어) 처리
# - 자연어 처리 하는 분야
#         - 자연어 이해 : 형태소분석 -> 의미분석 -> 대화분석
#         - 자연어 생성 : 대화분석 -> 다음 문장이나 단어 출력
# - 활용분야 : 맞춤법검사, 번역기, 검색엔진, 키워드 분석

# %% [markdown]
# # 2. 자연어 처리 절차
# - 전처리 : 단어, 어절 추출
# - 분석후보 생성 : 형태소 분리, 원형복원, 품사태깅
# - 불용어 처리 , 제약조건 규칙 확인
# - 분석

# %% [markdown]
# # 3. 한글 형태소 분석 엔진
# - KoNLPy : 파이썬 용 (JPype1 패키지 필수)
# - KOMORAN : 자바로 만든 형태소 분석기 (JAVA_HOME 시스템변수 필수)
# - HanNanum : 자바로 만든 형태소 분석기 (JAVA_HOME 시스템변수 필수)
# - kkma : 서울대학교 연구실에서 만듬
# - KoNLP : R용 자연어 처리기

# %%
! pip install JPype1-1.2.0-cp38-cp38-win_amd64.whl
# pip install KoNLPy
# Out:
# Processing d:\kks\src\10_자연어처리\jpype1-1.2.0-cp38-cp38-win_amd64.whl
# Installing collected packages: JPype1
# Successfully installed JPype1-1.2.0

# %%
text = """아름답지만 다소 복잡하기도 한 한국어는 전세계에서 13번째로 많이 사용되는 언어입니다.
"""

# %% [markdown]
# ## 3.1 HanNanum

# %%
from konlpy.tag import Hannanum
han = Hannanum()
han.analyze(text)
# Out:
# [[[('아름답', 'paa'), ('지만', 'ecs')],
#   [('아름답', 'paa'), ('지', 'ecs'), ('만', 'jxc')],
#   [('아름답', 'paa'), ('지', 'ecx'), ('말', 'px'), ('ㄴ', 'etm')]],
#  [[('다소', 'mag')], [('다소', 'ncn')]],
#  [[('복잡', 'ncn'), ('하기', 'ncn'), ('도', 'jxc')],
#   [('복잡', 'ncn'), ('하기', 'ncn'), ('도', 'ncn')],
#   [('복잡', 'ncps'), ('하기', 'ncn'), ('도', 'jxc')],
#   [('복잡', 'ncps'), ('하기', 'ncn'), ('도', 'ncn')],
#   [('복잡', 'ncps'), ('하', 'xsms'), ('기', 'etn'), ('도', 'jxc')]],
#  [[('하', 'pvg'), ('ㄴ', 'etm')],
#   [('한', 'nnc')],
#   [('한', 'ncn')],
#   [('한', 'nbn')],
#   [('하', 'px'), ('ㄴ', 'etm')]],
#  [[('한국어', 'ncn'), ('는', 'jxc')]],
#  [[('전세계', 'ncn'), ('에서', 'jca')],
#   [('전세', 'ncn'), ('계', 'ncn'), ('에서', 'jca')],
#   [('전', 'xp'), ('세계', 'ncn'), ('에서', 'jca')]],
#  [[('13', 'nnc'), ('번', 'nbu'), ('째', 'xsnu'), ('로', 'jca')]],
#  [[('많', 'paa'), ('이', 'xsa')], [('많이', 'mag')]],
#  [[('사용', 'ncpa'), ('되', 'xsvn'), ('는', 'etm')]],
#  [[('언어', 'ncn'), ('이', 'jp'), ('ㅂ니다', 'ef')]],
#  [[('.', 'sf')], [('.', 'sy')]]]

# %% [markdown]
# https://konlpy.org
# <pre>
#     api -> 위에 Comparison between POS tagging classes 클릭
#     Korean POS tags comparison chart 클릭 후 다른 이름으로 저장
# </pre>

# %%
# 형태소만
han.morphs(text)
# Out:
# ['아름답',
#  '지만',
#  '다소',
#  '복잡',
#  '하',
#  '기',
#  '도',
#  '하',
#  'ㄴ',
#  '한국어',
#  '는',
#  '전세계',
#  '에서',
#  '13번',
#  '째',
#  '로',
#  '많',
#  '이',
#  '사용',
#  '되',
#  '는',
#  '언어',
#  '이',
#  'ㅂ니다',
#  '.']

# %%
# 품사 태깅
print(han.pos(text,ntags=9)) #디폴트가 ntags=9
                             # 22 , 26 , 69가 있다.
# Out:
# [('아름답', 'P'), ('지만', 'E'), ('다소', 'M'), ('복잡', 'N'), ('하', 'X'), ('기', 'E'), ('도', 'J'), ('하', 'P'), ('ㄴ', 'E'), ('한국어', 'N'), ('는', 'J'), ('전세계', 'N'), ('에서', 'J'), ('13번', 'N'), ('째', 'X'), ('로', 'J'), ('많', 'P'), ('이', 'X'), ('사용', 'N'), ('되', 'X'), ('는', 'E'), ('언어', 'N'), ('이', 'J'), ('ㅂ니다', 'E'), ('.', 'S')]

# %%
# text 중에 형용사만 추출
pos_text22=han.pos(text,ntags=22)
[PA[0] for PA in pos_text22 if PA[1]=='PA']
# Out:
# ['아름답', '많']

# %%
# 명사만 추출
han.nouns(text)
# Out:
# ['복잡', '한국어', '전세계', '13번', '사용', '언어']

# %% [markdown]
# ## 3.2 Kkma

# %%
from konlpy.tag import Kkma
kkma = Kkma(max_heap_size=1024) # 힙메모리 사이즈 늘릴때 사용
print(kkma.morphs(text)) # 형태소 분석만
# Out:
# ['아름답', '지만', '다소', '복잡', '하', '기', '도', '한', '한국어', '는', '전세계', '에서', '13', '번째', '로', '많이', '사용', '되', '는', '언어', '이', 'ㅂ니다', '.']

# %%
print(kkma.pos(text)) # ntags 기본값은 30
# Out:
# [('아름답', 'VA'), ('지만', 'ECE'), ('다소', 'MAG'), ('복잡', 'NNG'), ('하', 'XSV'), ('기', 'ETN'), ('도', 'JX'), ('한', 'MDN'), ('한국어', 'NNG'), ('는', 'JX'), ('전세계', 'NNG'), ('에서', 'JKM'), ('13', 'NR'), ('번째', 'NNB'), ('로', 'JKM'), ('많이', 'MAG'), ('사용', 'NNG'), ('되', 'XSV'), ('는', 'ETD'), ('언어', 'NNG'), ('이', 'VCP'), ('ㅂ니다', 'EFN'), ('.', 'SF')]

# %%
# 보통명사만 추출
tagged_text = kkma.pos(text,56)
[t[0] for t in tagged_text if t[1]=='NNG']
# Out:
# ['복잡', '한국어', '전세계', '사용', '언어']

# %% [markdown]
# ## 3.3 Komoran

# %%
from konlpy.tag import Komoran
komoran = Komoran(max_heap_size = 1024) # 힙메모리 = 변수만 저장
print(komoran.morphs(text)) # 형태소추출
# Out:
# ['아름답', '지만', '다소', '복잡', '하', '기', '도', '한', '한국어', '는', '전', '세계', '에서', '13', '번', '째', '로', '많이', '사용', '되', '는', '언어', '이', 'ㅂ니다', '.']

# %%
#명사만
komoran.nouns(text)
# Out:
# ['한국어', '전', '세계', '번', '사용', '언어']

# %%
# 품사태깅
komoran.pos(text)
# Out:
# [('아름답', 'VA'),
#  ('지만', 'EC'),
#  ('다소', 'MAG'),
#  ('복잡', 'XR'),
#  ('하', 'XSA'),
#  ('기', 'ETN'),
#  ('도', 'JX'),
#  ('한', 'MM'),
#  ('한국어', 'NNP'),
#  ('는', 'JX'),
#  ('전', 'NNG'),
#  ('세계', 'NNG'),
#  ('에서', 'JKB'),
#  ('13', 'SN'),
#  ('번', 'NNB'),
#  ('째', 'XSN'),
#  ('로', 'JKB'),
#  ('많이', 'MAG'),
#  ('사용', 'NNG'),
#  ('되', 'XSV'),
#  ('는', 'ETM'),
#  ('언어', 'NNG'),
#  ('이', 'VCP'),
#  ('ㅂ니다', 'EF'),
#  ('.', 'SF')]

# %%
# 일반명사만 추출 (NNG)
t_text = komoran.pos(text)
[t[0] for t in t_text if t[1]=='NNG']
# Out:
# ['전', '세계', '사용', '언어']

# %%
komoran.nouns(text)
# Out:
# ['한국어', '전', '세계', '번', '사용', '언어']

# %% [markdown]
# # 4. 말뭉치

# %%
print(r'Hello\nWorld') # r: raw data 날 것 그대로 출력
print('Hello\nWorld')
# Out:
# Hello\nWorld
# Hello
# World

# %%
from konlpy.corpus import kolaw
data = kolaw.open('constitution.txt').read()
len(data)
# Out:
# 18884

# %%
from konlpy.corpus import kobill
data1 = kobill.open('1809892.txt').read()
len(data1)
# Out:
# 4929

# %% [markdown]
# # 5. 워드 클라우드

# %%
word_list = komoran.nouns('%r'%data)
print('명사 출현 수 : ',len(word_list))
print('출현 명사 종류 수 : ', len(set(word_list)))
print('한 단어당 평균 반복 횟수 : ',len(word_list)/len(set(word_list)))
# Out:
# 명사 출현 수 :  3361
# 출현 명사 종류 수 :  891
# 한 단어당 평균 반복 횟수 :  3.772166105499439

# %%
# 한개의 text로 묶기
text = ' '.join(word_list)
text
# Out:
# '대한민국 헌법 유구 한 역사 전통 국민 운동 건립 대한민국 임시 정부 법통 불의 항거 민주 이념 계승 조국 민주개혁 평화 통일 사명 입각 정의 인도 동포애 민족 단결 사회 폐습 불의 타파 자율 조화 바탕 자유 민주 기본 질서 정치 경제 사회 문화 영역 각인 기회 능력 최고 도로 발휘 자유 권리 책임 의무 완수 안 국민 생활 균등 향상 밖 항구 세계 평화 인류 공영 이바지 우리들의 자손 안전 자유 행복 확보 것 다짐 년 7월 12일 제정 차 개정 헌법 국회 의결 국민 투표 개정 장 강 대한민국 민주공화국 대한민국 주권 국민 권력 국민 대한민국 국민 요건 법률 국가 법률 바 재외국민 보호 의무 대한민국 영토 한반도 부속 도서 대한민국 통일 지향 자유 민주 기본 질서 입각 평화 통일 정책 수립 추진 대한민국 국제 평화 유지 노력 침략 전쟁 부인 국군 국가 안전 보장 국토방위 신성 의무 수행 사명 정치 중립 준수 헌법 체결 공포 조약 일반 승인 국제 법규 국내법 효력 외국인 국제법 조약 바 지위 보장 공무원 국민 전체 봉사자 국민 책임 공무원 신분 정치 중립 법률 바 보장 정당 설립 자유 복수 정당 보장 정당 목적 조직 활동 민주 국민 정치 의사 형성 참여 필요 조직 정당 법률 바 국가 보호 국가 법률 바 정당 운영 필요 자금 보조 수 정당 목적 활동 민주 기본 질서 위배 때 정부 헌법재판소 해산 제소 수 정당 헌법재판소 심판 해산 국가 전통문화 계승 발전 민족 문화 창달 노력 장 국민의 권리와 의무 국민 인간 존엄 가치 행복 추구 권리 국가 개인 불가침 기본 인권 확인 보장 의무 국민 법 앞 평등 성별 종교 사회 신분 정치 경제 사회 문화 생활 영역 차별 사회 특수 계급 제도 인정 형태 창설 수 훈장 등 영전 자 효력 특권 국민 신체의 자유 법률 체포 구속 압수 수색 심문 법률 적법 절차 처벌 보안처분 강제 노역 국민 고문 형사 진술 강요 체포 구속 압수 수색 때 적법 절차 검사 신청 법관 발부 영장 제시 현행범 인 경우 장기 년 이상 형 해당 죄 도피 증거 인멸 염려 때 사후 영장 청구 수 체포 구속 때 변호인 조력 권리 형사 피고인 변호인 수 때 법률 바 국가 변호인 체포 구속 이유 변호인 조력 권리 고지 체포 구속 체포 구속 자 가족 등 법률 자 이유 일시 장소 지체 통지 체포 구속 때 적 부의 심사 법원 청구 권리 피고인 자백 고문 폭행 협박 구속 장기 기 망 기타 방법 자의 진술 것 인정 때 정식 재판 피고인 자백 유일한 증거 때 유죄 증거 이유 처벌 수 국민 행위 법률 범죄 구성 행위 소추 범죄 처벌 국민 소급 입법 참정권 제한 재산권 박탈 국민 행위 친족 행위 이익한 처우 국민 거주 이전 자유 국민 직업 선택 자유 국민 주거 자유 침해 주거 압수 수색 때 검사 신청 법관 발부 영장 제시 국민 사생활의 비밀과 자유 침해 국민 통신 비밀 침해 국민 양심의 자유 국민 종교의 자유 국교 인정 종교 정치 분리 국민 언론 출판 자유 집회 결사의 자유 언론 출판 허가 검열 집회 결사 허가 인정 통신 방송 시설 기준 신문 기능 보장 필요 사항 법률 언론 출판 타인 명예 권리 공중도덕 사회 윤리 침해 언론 출판 타인 명예 권리 침해 때 피해자 피해 배상 청구 수 국민 학문 예술 자유 저작자 발명가 과학기술 자와 예술가 권리 법률 보호 국민 재산권 보장 내용 한계 법률 재산권 행사 공공복리 공공필요 재산권 수용 사용 제한 보상 법률 보상 지급 국민 법률 바 선거권 국민 법률 바 공무담임권 국민 법률 바 국가 기관 문서 청원 권리 국가 청원 심사 의무 국민 헌법 법률 법관 법률 재판을 받을 권리 군인 군무원 국민 대한민국 영역 안 군사 기밀 초병 초소 유독 음식물 공급 포로 군용 물 죄 중 법률 경우 비상계엄 선포 경우 제외 군사법원 재판 국민 신속 재판을 받을 권리 형사 피고인 상당 이유 지체 공개 재판을 받을 권리 형사 피고인 유죄 판결 확정 때 무죄 추정 형사 피해자 법률 바 사건 재판 절차 진술 수 형사 피의자 형사 피고인 구금 자 법률 기소 처분 무죄 판결 때 법률 바 국가 보상 청구 수 공무원 직무 불법행위 손해 국민 법률 바 국가 공공단체 배상 청구 수 경우 공무원 자신 책임 면제 군인 군무원 경찰 공무원 기타 법률 자 전투 훈련 등 직무 집행 관련 손해 법률 보상 외 국가 공공단체 공무원 직무 불법행위 배상 청구 수 타인 범죄 행위 생명 신체 피해 국민 법률 바 국가 구조 수 국민 능력 균등 교육 권리 국민 보호 자녀 초등 교육 법률 교육 의무 의무 교육 무상 교육 자주성 전문 정치 중립 대학 자율 법률 바 보장 국가 평생 교육 진흥 학교 교육 평생 교육 포함 교육 제도 운영 교육 재정 교원 지위 기본 사항 법률 국민 근로 권리 국가 사회 경제 방법 근로자 고용 증진 적정 임금 보장 노력 법률 바 최저임금 시행 국민 근로 의무 국가 근로 의무 내용 조건 민주주의 원칙 법률 근로 조건 기준 인간 존엄성 보장 법률 여자 근로 보호 고용 임금 근로 조건 차별 연소자 근로 보호 국가 유공자 군경 전 몰 군경 유가족 법률 바 우선 근로 기회 부여 근로자 근로 조건 향상 자주 단결 단체교섭 단체행동권 공무원 근로자 법률 자 단결 단체교섭 단체행동권 법률 방위 산업체 종사 근로자 단체행동권 법률 바 제한 인정 수 국민 인간 다운 생활 권리 국가 사회 보장 사회 복지 증진 노력 의무 국가 여자 복지 권익 향상 노력 국가 노인 청소년 복지 향상 정책 실시 의무 신체 장애자 질병 노령 기타 사유 생활 능력 국민 법률 바 국가 보호 국가 재해 예방 위험 국민 보호 노력 국민 건강 환경 생활 권리 국가 국민 환경 보전 노력 환경권 내용 행사 법률 국가 주택 개발 정책 등 국민 주거 생활 수 노력 혼인 가족생활 개인 존엄 양성 평등 기초 성립 유지 국가 보장 국가 모성 보호 노력 국민 보건 국가 보호 국민 자유 권리 헌법 열거 이유 경시 국민 자유 권리 국가 안전 보장 질서 유지 공공복리 필요 경우 법률 제한 수 제한 경우 자유 권리 본질 내용 침해 수 국민 법률 바 납세 의무 국민 법률 바 국방의 의무 병역 의무 이행 이익한 처우 장 국회 입법 국회 국회 국민 보통 평등 직접 비밀 선거 선출 국회의원 구성 국회의원 수 법률 이상 국회의원 선거구 비례대표제 기타 선거 사항 법률 국회의원 임기 년 국회의원 법률 직 수 국회의원 현행범 인 경우 제외 회기 중 국회 동의 체포 구금 국회의원 회 기전 체포 구금 때 현행범 인 국회 요구 회기 중 석방 국회의원 국회 직무 발언 표결 국회 외 책임 국회의원 청렴 의무 국회의원 국가 이익 양심 직무 국회의원 지위 남용 국가 공공단체 기업체 계약 처분 재산 권리 이익 직위 취득 타인 취득 알선 수 국회 정기회 법률 바 회 집회 국회 임시회 대통령 국회 재적 의원 분 이상 요구 집회 정기회 회기 일 임시회 회기 일 초과 수 대통령 임시회 집회 요구 때 기간 집회 요구 이유 명시 국회 의장 인과 부의장 인 선출 국회 헌법 법률 규정 적의 원 과반수 출석 출석 의원 과반수 찬성 의결 가부 동수 때 부결 것 국회 회의 공개 출석 의원 과반수 찬성 의장 국가 안전 보장 필요 인정 때 공개 수 공개 회의 내용 공표 법률 바 국회 제출 법률 안 기타 의안 회기 중 의결 이유 폐기 국회의원 임기 만료 때 국회의원 정부 법률 안 제출 수 국회 의결 법률 안 정부 이송 일 이내 대통령 공포 법률 안 이의 때 대통령 항의 기간 내 이의 서 국회 환부 재의 요구 수 국회 폐회 중 대통령 법률 안 일부 법률 안 수정 재의 요구 수 재의 요구 때 국회 재의 재적 의원 반수 출석 출석 의원 3분 이상 찬성 전과 의결 법률 안 법률 확정 대통령 항의 기간 내 공포 재의 요구 때 법률 안 법률 확정 대통령 항 항의 규정 확정 법률 지체 공포 항 법률 확정 후 항 확정 법률 정부 이송 후 일 이내 대통령 공포 때 국회 의장 공포 법률 규정 공포 날 일 경과 효력 발생 국회 국가 예산안 심의 확정 정부 회계 연도 예산안 편성 회계 연도 개시 일 전 국회 제출 국회 회계 연도 개시 일 전 의결 회계 연도 개시 때 예산안 의결 때 정부 국회 예산안 의결 때 다음 목적 경비 전년도 예산 집행 수 헌법 법률 설치 기관 시설 유지 운영 법률 지출 의 ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# 설정값 미설정
wordc = WordCloud()
wordc.generate(text)
plt.figure(figsize=(10,5))
plt.imshow(wordc, interpolation='bilinear') # interpolation 보간법

# %%
# 설정값 설정
wordc = WordCloud(background_color='white',
                  max_words=200,
                  font_path='c:/Windows/Fonts/malgun.ttf',
                  relative_scaling=0.2)
wordc.generate(text)
plt.figure(figsize=(10,5))
plt.imshow(wordc, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# 일반명사만
tagged_data = komoran.pos(data)
data3=[t[0] for t in tagged_data if (t[1]=='NNG')]

# %%
# text 하나로
text1 = ' '.join(data3)

# %%
wordc = WordCloud(background_color='white',
                  max_words=200,
                  font_path='c:/Windows/Fonts/malgun.ttf',
                  relative_scaling=0.2)
wordc.generate(text1)
plt.figure(figsize=(10,5))
plt.imshow(wordc, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# 불용어 처리 ( 불용어 사전 + 불용어 추가)

# %%
from wordcloud import STOPWORDS
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
# 사실상 불용어 사전에 한국어는 없다.
# 반드시 set으로 추가
stopwords = STOPWORDS | ENGLISH_STOP_WORDS | set(['때','대통령'])

# %%
wordc = WordCloud(background_color='white',
                  max_words=200,
                  stopwords=stopwords,
                  font_path='c:/Windows/Fonts/malgun.ttf',
                  relative_scaling=0.2)
wordc.generate(text1)
plt.figure(figsize=(10,5))
plt.imshow(wordc, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# 마스킹
# wordcloud를 지정된 마스크 이미지에 맞도록 표시
from PIL import Image
import numpy as np
img = Image.open('south_korea.png').convert('RGBA')
# png : 'RGBA' , jpg : 'RGB'
mask = Image.new('RGB',img.size,(0,0,0)) # 마스킹베이스
mask.paste(img) # 마스킹복사
mask = np.array(mask) # 넘파이배열로 변환

# %%
wordcloud = WordCloud(background_color='white',
                      max_words=2000,
                      font_path='c:/Windows/Fonts/malgun.ttf',
                      mask=mask,
                      relative_scaling=0.2,
                      random_state=42)
wordcloud.generate(text1)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 719.5, 1123.5, -0.5)

# %%
# 파일로 저장
wordcloud.to_file('result.png')

# %%
# 마스킹
# wordcloud를 지정된 마스크 이미지에 맞도록 표시
from PIL import Image
import numpy as np
img = Image.open('test3.png').convert('RGBA')
# png : 'RGBA' , jpg : 'RGB'
mask = Image.new('RGB',img.size,(0,0,0)) # 마스킹베이스
mask.paste(img) # 마스킹복사
mask = np.array(mask) # 넘파이배열로 변환
wordcloud = WordCloud(background_color='white',
                      max_words=2000,
                      font_path='c:/Windows/Fonts/malgun.ttf',
                      mask=mask,
                      relative_scaling=0.2,
                      random_state=42)
wordcloud.generate(text1)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 899.5, 899.5, -0.5)

# %% [markdown]
# # 6. 단어 빈도수 계산

# %%
import nltk
# %config InlineBackend.figure_format ='retina'
# nltk는 영어전용 한글 설정을 해줘야 안깨진다
plt.rc('font',family='Malgun Gothic')
nltk.Text(word_list).plot(10)

# %% [markdown]
# # 7. 워드 임베딩
# - 단어간 유사성 도출

# %%
import requests
from bs4 import BeautifulSoup
import re,urllib

# %%
# 뉴스기사 link들 list 가져오기
rss_url = 'https://fs.jtbc.joins.com//RSS/economy.xml'
jtbc_eco = requests.get(rss_url)
soup = BeautifulSoup(jtbc_eco.content,'xml')
items = soup.select('item')
link_list = []
for item in items:
    link = item.select_one('link').text
    link_list.append(link)
link_list
# Out:
# ['https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997856',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997858',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997873',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997839',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997816',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997838',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997841',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997663',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997660',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997664',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997622',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997623',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997533',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997488',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997507',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997352',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997298',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997291',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997338',
#  'https://news.jtbc.joins.com/article/article.aspx?news_id=NB11997300']

# %%
# 뉴스 기사들 명사들만 뽑아 워드 임베딩하기 좋게 만들기
from konlpy.tag import Kkma
kkma = Kkma()
news = []
for link in link_list:
    new_response = requests.get(link)
    new_soup = BeautifulSoup(new_response.content,'html.parser')
    news_title = new_soup.select_one('h3#jtbcBody').text
    news_content = new_soup.select_one('div#articlebody > div.article_content').text
    contents = news_title+' '+news_content
    news.append(kkma.nouns(contents))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-4d5be4d21a0f> in <module>
#       9     news_content = new_soup.select_one('div#articlebody > div.article_content').text
#      10     contents = news_title+' '+news_content
# ---> 11     news.append([t[0] for t in kkma.nouns(contents) if t[1]=='NNG'])
#
# <ipython-input-22-4d5be4d21a0f> in <listcomp>(.0)
#       9     news_content = new_soup.select_one('div#articlebody > div.article_content').text
#      10     contents = news_title+' '+news_content
# ---> 11     news.append([t[0] for t in kkma.nouns(contents) if t[1]=='NNG'])
#
# IndexError: string index out of range

# %%
# 워드임베딩
from gensim.models import Word2Vec

# %%
model = Word2Vec(news,
                 size=100, # 특징 백터의 차원
                 window=5,    # 문장 내 현재 단어와 예측 단어 사이의 최대 거리 
                 min_count=2, # 총 빈도가 이보다 낮은 모든 단어 무시
                 workers=-1  # 모델을 훈련시킬 쓰레드 수
                 )
model.wv.most_similar('코로나',topn=5)
# Out:
# [('전체', 0.3206270635128021),
#  ('확률', 0.3135984539985657),
#  ('평소', 0.2803000211715698),
#  ('권유', 0.26912185549736023),
#  ('그때', 0.2527617812156677)]
